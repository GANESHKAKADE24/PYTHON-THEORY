# %% [markdown]
# # Python- OOPS Concepts By  Ganesh Kakade

# %% [markdown]
# # Class and object declaration

# %% [markdown]
# A class is a collection of objects. A class contains the blueprints or the prototype from which the objects are being created. It is a logical entity that contains some attributes and methods.

# %% [markdown]
# Classes are created by keyword class.
# Attributes are the variables that belong to a class.
# Attributes are always public and can be accessed using the dot (.) operator. Eg.: Myclass.Myattribute

# %% [markdown]
# # Objects

# %% [markdown]
# The object is an entity that has a state and behavior associated with it

# %% [markdown]
# An object consists of :<br>
#
# State: It is represented by the attributes of an object. It also reflects the properties of an object.<br>
# Behavior: It is represented by the methods of an object. It also reflects the response of an object to other objects.<br>
# Identity: It gives a unique name to an object and enables one object to interact with other objects.

# %%
class computer:#define a class
    def config(self):#defining method
        print("Hi my name is function")
        
com=computer()# creating instance of class called object
com.config()#calling the method from using object
# Out:
# Hi my name is function

# %% [markdown]
# ## __init__ method

# %% [markdown]
# The __init__ method is similar to constructors in C++ and Java. It is run as soon as an object of a class is instantiated. The method is useful to do any initialization you want to do with your object.

# %%
class computer:#define a class
    
    def __init__(self,ram,cpu):
        self.ram=ram
        self.cpu=cpu
    def config(self):#defining method
        print("com propoerties",self.ram,self.cpu)
        
com=computer("8gb","i5")# creating instance of class called object
com.config()#
# Out:
# com propoerties 8gb i5

# %% [markdown]
# # Types of variables in Python

# %% [markdown]
# **Instance variable**- When we declare variables inside class methods we call it as Instance variable<br>
# **Class variable**- When we Declare variables inside the class but not in the methods then we call it Class variable

# %% [markdown]
# ## Different Types of methods<br>
#
# 1- Class Methods<br>
# 2- Static methods<br>
# 3- Instance Methods<br>

# %% [markdown]
# Accessor and Mutator methods<br>
#
# Accessor is like get function or getter which returns the value of object that we are passing.
# Mutator ism like set function which used to set values of object

# %% [markdown]
# ## Decorators

# %% [markdown]
# Decorators are used for declaring particular methods which belongs to class variables instead of instance variables

# %% [markdown]
# ## Inner Class In python

# %% [markdown]
# We can create object of inner class inside the outer class or we can create the object of inner class in outeside the outer class probvided that u need to call outer class name to call it.

# %% [markdown]
# # for eg.
# Class Demo:
#
#     Class Inner:
#
# obj= Demo.Inner()

# %% [markdown]
# # Inheritance in Python

# %% [markdown]
# using features of existing class

# %% [markdown]
# Single Inheritance:
# Single-level inheritance enables a derived class to inherit characteristics from a single-parent class.<br>
#
# Multilevel Inheritance:
# Multi-level inheritance enables a derived class to inherit properties from an immediate parent class which in turn inherits properties from his parent class.<br>
#
# Hierarchical Inheritance:
# Hierarchical level inheritance enables more than one derived class to inherit properties from a parent class.<br>
#
# Multiple Inheritance:
# Multiple level inheritance enables one derived class to inherit properties from more than one base class.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# Single Inheritance
class Animal:  
    def speak(self):  
        print("Animal Speaking")  
#child class Dog inherits the base class Animal  
class Dog(Animal):  
    def bark(self):  
        print("dog barking")  
d = Dog()  
d.bark()  
d.speak()
# Out:
# dog barking
# Animal Speaking

# %%
# Multilevel-Inheritance
class Animal:  
    def speak(self):  
        print("Animal Speaking")  
#The child class Dog inherits the base class Animal  
class Dog(Animal):  
    def bark(self):  
        print("dog barking")  
#The child class Dogchild inherits another child class Dog  
class DogChild(Dog):  
    def eat(self):  
        print("Eating bread...")  
d = DogChild()  
d.bark()  
d.speak()  
d.eat()
# Out:
# dog barking
# Animal Speaking
# Eating bread...

# %% [markdown]
# # Super Word

# %% [markdown]
# # MRO- Method resolution order
#   When we are having multiple parent class the we are unable to call or choose one of them for calling the objects

# %% [markdown]
# # Polymorphism

# %% [markdown]
# Polymorphism simply means having many forms. For example, we need to determine if the given species of birds fly or not, using polymorphism we can do this using a single function.

# %% [markdown]
# # Encapsulation

# %% [markdown]
# Encapsulation is one of the fundamental concepts in object-oriented programming (OOP). It describes the idea of wrapping data and the methods that work on data within one unit. This puts restrictions on accessing variables and methods directly and can prevent the accidental modification of data. To prevent accidental change, an object’s variable can only be changed by an object’s method. Those types of variables are known as private variables.

# %% [markdown]
#  convention by prefixing the name of the member by a single underscore “_”

# %% [markdown]
# # Data Abstraction

# %% [markdown]
# It hides the unnecessary code details from the user. Also,  when we do not want to give out sensitive parts of our code implementation and this is where data abstraction came.
#
# Data Abstraction in Python can be achieved through creating abstract classes.

# %% [markdown]
# ## Operator Overloading

# %% [markdown]
# When u want to perform any operation on object u need to define particular method inside the class

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ducking method

# %% [markdown]
# ## Method overloading

# %% [markdown]
#  python does not support method overloading by default. But there are different ways to achieve method overloading in Python.

# %%
def product(a, b):
    p = a * b
    print(p)
 
 #Second product method
# Takes three argument and print their
# product
 
def product(a, b, c):
    p = a * b*c
    print(p)
# Uncommenting the below line shows an error
# product(4, 5)
 
#This line will call the second product method
product(4, 5, 5)
# Out:
# 100

# %%
# We can use this kind of defalut parameter passing to avoid method overloading
def addnum(a=0,b=0,c=0):
    p=0
    p=a+b+c
    print(p)
    
addnum(3,2,10)
addnum(6)
addnum(33,12)
# Out:
# 15
# 6
# 45

# %% [markdown]
# # Method Overrding

# %% [markdown]
# Method overriding is an ability of any object-oriented programming language that allows a subclass or child class to provide a specific implementation of a method that is already provided by one of its super-classes or parent classes. When a method in a subclass has the same name, same parameters or signature and same return type(or sub-type) as a method in its super-class, then the method in the subclass is said to override the method in the super-class.

# %%
class Animal:
    # properties
    multicellular = True
    # Eukaryotic means Cells with Nucleus
    eukaryotic = True

    # function breathe
    def breathe(self):
        print("I breathe oxygen.")

        # function feed
    def feed(self):
        print("I eat food.")

# %%
class Herbivorous(Animal):
    
    # function feed
    def feed(self):
         print("I eat only plants. I am vegetarian.")

# %%
herbi = Herbivorous()
herbi.feed()
# calling some other function
herbi.breathe()
# Out:
# I eat only plants. I am vegetarian.
# I breathe oxygen.
